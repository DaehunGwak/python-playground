# %% [markdown]
# # 1. set-up environments

# %%
import os
import json

keys: dict = {}

with open('api-key.json') as key_file:
    keys = json.load(key_file)

os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_API_KEY'] = keys['langchain-personal-key'] 
os.environ['OPENAI_API_KEY'] = keys['openai-key']

# %% [markdown]
# # 2. set-up openai model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-3.5-turbo")

# %% [markdown]
# # 3. excute sample message

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="프로그래밍 랭귀지 이름을 말하면 서정적인 시를 써줘. 최대한 길게 부탁할께."),
    HumanMessage(content="python"),
]

ai_message = model.invoke(messages)
ai_message.content
# Out:
# '한 줄 한 줄 코딩을 느끼며  \n파이썬의 아름다움을 느껴보자  \n들여쓰기로 만들어지는 그 인덴트  \n우아한 문법 속에 숨어있는 비밀  \n\n함수와 클래스가 춤을 추며  \n데이터를 표현하고 연산을 수행하는데  \n모듈과 패키지가 우리를 감싸는데  \n파이썬의 세계는 어지러운 듯하면서도  \n\n간결함과 강력함이 공존하는  \n그 언어의 매력에 빠져들게  \n파이썬이여, 너의 빛나는 문법으로  \n나의 세계를 빛내 주소서.'
